# %%
#!/usr/bin/python

# Import required modules
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as mpltkr
import matplotlib.colors as mplcolors
import matplotlib.patches as mplpatches
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import gaussian_kde

# Import COSMO style toolkit
import cosmoplot.colorbars as cosmocbars
import cosmoplot.style as cosmostyle
import cosmoplot.utils as cosmoutils

cosmostyle.set_style('article')
colorList = cosmostyle.color_cycle

# %% [markdown]
# # Distance Histograms

# %% [markdown]
# ## Linear Kernel Distance

# %%
# Load FPS-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 15.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 125.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', 
                verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_3.5_linear_FPS.png', bbox_inches='tight')
plt.show()

# %%
# Load FPS-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 15.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 125.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_3.5_linear_FPS.png', bbox_inches='tight')
plt.show()

# %%
# Load FPS-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 8.0])
axsDist.set_xlim([0.01, 1.0])
axsMinDist.set_ylim([0.0, 80.0])
axsMinDist.set_xlim([0.01, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_6.0_linear_FPS.png', bbox_inches='tight')
plt.show()

# %%
# Load FPS-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 8.0])
axsDist.set_xlim([0.01, 1.0])
axsMinDist.set_ylim([0.0, 80.0])
axsMinDist.set_xlim([0.01, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_6.0_linear_FPS.png', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Linear/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 15.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 125.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_3.5_linear_random.png', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Linear/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 15.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 125.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0, 1:], minDistDD[1, 1:], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1],  alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_3.5_linear_random.png', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Linear/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 8.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 50.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_6.0_linear_random.png', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Linear/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 8.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 50.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_6.0_linear_random.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Gaussian Kernel Distance

# %%
# Load FPS-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 4.0])
axsDist.set_xlim([0.001, 10.0])
axsMinDist.set_ylim([0.0, 40.0])
axsMinDist.set_xlim([0.001, 10.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', 
                verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_3.5_Gaussian_FPS.png', bbox_inches='tight')
plt.show()

# %%
# Load FPS-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 4.0])
axsDist.set_xlim([0.01, 10.0])
axsMinDist.set_ylim([0.0, 40.0])
axsMinDist.set_xlim([0.01, 10.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.95, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='top', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.95, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='right', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_3.5_Gaussian_FPS.png', bbox_inches='tight')
plt.show()

# %%
# Load FPS-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 6.0])
axsDist.set_xlim([0.01, 1.0])
axsMinDist.set_ylim([0.0, 80.0])
axsMinDist.set_xlim([0.01, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_6.0_Gaussian_FPS.png', bbox_inches='tight')
plt.show()

# %%
# Load FPS-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 6.0])
axsDist.set_xlim([0.01, 1.0])
axsMinDist.set_ylim([0.0, 80.0])
axsMinDist.set_xlim([0.01, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_6.0_Gaussian_FPS.png', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/3.5/Gaussian/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 5.0])
axsDist.set_xlim([0.001, 10.0])
axsMinDist.set_ylim([0.0, 30.0])
axsMinDist.set_xlim([0.001, 10.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_3.5_Gaussian_random.png', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/3.5/Gaussian/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 5.0])
axsDist.set_xlim([0.001, 10.0])
axsMinDist.set_ylim([0.0, 30.0])
axsMinDist.set_xlim([0.001, 10.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1],  alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_3.5_Gaussian_random.png', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_1k/Histograms/SOAP/6.0/Gaussian/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 6.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 30.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_6.0_Gaussian_random.png', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/IZAonDEEM_10k/Histograms/SOAP/6.0/Gaussian/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 6.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 30.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_6.0_Gaussian_random.png', bbox_inches='tight')
plt.show()
